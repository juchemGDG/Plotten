# %% [markdown]
# # 📘 Grundlegende Datenstrukturen in Python (Klasse 8/9)
#
# Datenstrukturen helfen uns, mehrere Werte übersichtlich zu speichern und zu organisieren.
# In diesem Notebook lernst du:
# - Variablen
# - Listen
# - Tupel
# - Dictionaries
# - Sets

# %% [markdown]
# ## 🔢 1. Variablen
# Eine Variable ist ein „Behälter“ für einen Wert.

# %%
name = "Lina"
alter = 14
pi = 3.14

print(name, alter, pi)

# %% [markdown]
# ### ✏️ Mini-Übung
# Speichere deinen Lieblingsfilm in einer Variable `film` und gib ihn aus.

# %% [markdown]
# ## 📚 2. Listen
# Listen sind geordnete Sammlungen von Werten und können verändert werden.

# %%
fruechte = ["Apfel", "Banane", "Kirsche"]
print(fruechte)

# %%
fruechte.append("Orange")
print(fruechte)

# %%
fruechte[1] = "Birne"
print(fruechte)

# %%
fruechte.remove("Apfel")
print(fruechte)

# %% [markdown]
# ### ✏️ Mini-Übung
# Erstelle eine Liste `lieblingszahlen` mit drei Zahlen und füge eine weitere hinzu.

# %% [markdown]
# ## 🔒 3. Tupel
# Tupel sind wie Listen, aber unveränderbar.

# %%
koordinaten = (10, 20)
print(koordinaten)

# %% [markdown]
# ### ✏️ Mini-Übung
# Erstelle ein Tupel `geburtsdatum` mit Tag, Monat und Jahr.

# %% [markdown]
# ## 🗂️ 4. Dictionaries
# Dictionaries speichern Werte als **Schlüssel → Wert**.

# %%
schueler = {
    "name": "Lina",
    "alter": 14,
    "klasse": "8b"
}

print(schueler["name"])

# %%
schueler["alter"] = 15
print(schueler)

# %%
schueler["lieblingsfach"] = "Mathe"
print(schueler)

# %% [markdown]
# ### ✏️ Mini-Übung
# Erstelle ein Dictionary `auto` mit den Schlüsseln `marke`, `modell`, `baujahr`.

# %% [markdown]
# ## 🧪 6. Abschlussaufgabe
# Erstelle ein Dictionary `klasse` mit:
# - einer Liste aller Schülernamen
# - einem Tupel mit Raumkoordinaten `(x, y)`
#
# Gib anschließend alle Werte einzeln aus.
